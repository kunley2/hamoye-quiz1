# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
# Out:
# C:\Users\HP\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\HP\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\HP\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\HP\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
climate_df=pd.read_csv('https://raw.githubusercontent.com/WalePhenomenon/climate_change/master/fuel_ferc1.csv')

# %%
climate_df
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 0        f1_fuel_1994_12_1_0_7                 1         1994
# 1       f1_fuel_1994_12_1_0_10                 1         1994
# 2        f1_fuel_1994_12_2_0_1                 2         1994
# 3        f1_fuel_1994_12_2_0_7                 2         1994
# 4       f1_fuel_1994_12_2_0_10                 2         1994
# ...                        ...               ...          ...
# 29518  f1_fuel_2018_12_12_0_13                12         2018
# 29519   f1_fuel_2018_12_12_1_1                12         2018
# 29520  f1_fuel_2018_12_12_1_10                12         2018
# 29521  f1_fuel_2018_12_12_1_13                12         2018
# 29522  f1_fuel_2018_12_12_1_14                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
a = [1,2,3,4,5,6]
b = [13, 21, 34]

# %%
a.extend(b)
print(a)
# Out:
# [1, 2, 3, 4, 5, 6, 13, 21, 34, 13, 21, 34]

# %%
np.eye(3)
# Out:
# array([[1., 0., 0.],
#        [0., 1., 0.],
#        [0., 0., 1.]])

# %%
# finding the fuel type that has the minimum cost per unit burned
sns.barplot(data=climate_df,x='fuel_type_code_pudl',y='fuel_cost_per_unit_burned')
plt.yscale('log')
plt.show()

# %%
climate_df.describe()
# Out:
#        utility_id_ferc1   report_year  fuel_qty_burned  fuel_mmbtu_per_unit  \
# count      29523.000000  29523.000000     2.952300e+04         29523.000000
# mean         118.601836   2005.806050     2.622119e+06             8.492111
# std           74.178353      7.025483     9.118004e+06            10.600220
# min            1.000000   1994.000000     1.000000e+00             0.000001
# 25%           55.000000   2000.000000     1.381700e+04             1.024000
# 50%          122.000000   2006.000000     2.533220e+05             5.762694
# 75%          176.000000   2012.000000     1.424034e+06            17.006000
# max          514.000000   2018.000000     5.558942e+08           341.260000
#
#        fuel_cost_per_unit_burned  fuel_cost_per_unit_delivered  \
# count               29523.000000                  2.952300e+04
# mean                  208.649031                  9.175704e+02
# std                  2854.490090                  6.877593e+04
# ...

# %%
climate_df.isnull().sum()
# Out:
# record_id                         0
# utility_id_ferc1                  0
# report_year                       0
# plant_name_ferc1                  0
# fuel_type_code_pudl               0
# fuel_unit                       180
# fuel_qty_burned                   0
# fuel_mmbtu_per_unit               0
# fuel_cost_per_unit_burned         0
# fuel_cost_per_unit_delivered      0
# fuel_cost_per_mmbtu               0
# dtype: int64

# %%
# finding the number of missing rolls over the total roll
(180/29523)*100
# Out:
# 0.609694136774718

# %%
# finding the correlation
climate_df.corr()
# Out:
#                               utility_id_ferc1  report_year  fuel_qty_burned  \
# utility_id_ferc1                      1.000000     0.093323        -0.057447
# report_year                           0.093323     1.000000         0.012952
# fuel_qty_burned                      -0.057447     0.012952         1.000000
# fuel_mmbtu_per_unit                  -0.066946    -0.110853        -0.080946
# fuel_cost_per_unit_burned            -0.037863     0.013599        -0.018535
# fuel_cost_per_unit_delivered         -0.016414    -0.014043        -0.003551
# fuel_cost_per_mmbtu                   0.006122     0.010261        -0.001896
#
#                               fuel_mmbtu_per_unit  fuel_cost_per_unit_burned  \
# utility_id_ferc1                        -0.066946                  -0.037863
# report_year                             -0.110853                   0.013599
# fuel_qty_burned                         -0.080946                  -0.018535
# ...

# %%
# finding the fuel cost per unit delivered for each year
plt.figure(figsize=(8,8))
sns.lineplot(data=climate_df,x='report_year',y='fuel_cost_per_unit_delivered')
plt.grid(True,axis='x',which='both')
plt.yscale('log')
plt.show()

# %%
from scipy.stats import skew,kurtosis

# %%
# finding the skew of fuel quantity burned
skew(climate_df['fuel_qty_burned'])
# Out:
# 15.850690077422112

# %%
# finding the kurtosis of fuel quantity burned
kurtosis(climate_df['fuel_qty_burned'])
# Out:
# 651.2589365474387

# %%
climate_df.head(20)
# Out:
#                  record_id  utility_id_ferc1  report_year  \
# 0    f1_fuel_1994_12_1_0_7                 1         1994
# 1   f1_fuel_1994_12_1_0_10                 1         1994
# 2    f1_fuel_1994_12_2_0_1                 2         1994
# 3    f1_fuel_1994_12_2_0_7                 2         1994
# 4   f1_fuel_1994_12_2_0_10                 2         1994
# 5   f1_fuel_1994_12_2_0_13                 2         1994
# 6    f1_fuel_1994_12_2_1_1                 2         1994
# 7   f1_fuel_1994_12_2_1_10                 2         1994
# 8   f1_fuel_1994_12_2_2_10                 2         1994
# 9    f1_fuel_1994_12_4_0_1                 4         1994
# 10   f1_fuel_1994_12_4_0_2                 4         1994
# 11   f1_fuel_1994_12_4_0_4                 4         1994
# 12   f1_fuel_1994_12_4_0_5                 4         1994
# 13   f1_fuel_1994_12_6_0_1                 6         1994
# 14   f1_fuel_1994_12_6_0_2                 6         1994
# ...

# %%
fuel_type=climate_df.groupby('fuel_type_code_pudl')
coal_g=fuel_type.get_group('coal')

# %%
coal_g
# Out:
#                       record_id  utility_id_ferc1  report_year  \
# 0         f1_fuel_1994_12_1_0_7                 1         1994
# 1        f1_fuel_1994_12_1_0_10                 1         1994
# 2         f1_fuel_1994_12_2_0_1                 2         1994
# 3         f1_fuel_1994_12_2_0_7                 2         1994
# 5        f1_fuel_1994_12_2_0_13                 2         1994
# ...                         ...               ...          ...
# 29503  f1_fuel_2018_12_191_1_14               191         2018
# 29510   f1_fuel_2018_12_403_0_2               403         2018
# 29516    f1_fuel_2018_12_12_0_8                12         2018
# 29517   f1_fuel_2018_12_12_0_10                12         2018
# 29521   f1_fuel_2018_12_12_1_13                12         2018
#
#            plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                  rockport                coal       ton        5377489.0
# ...

# %%
df_1994=coal_g.groupby('report_year').get_group(1994)

# %%
df_1994
# Out:
#                     record_id  utility_id_ferc1  report_year  \
# 0       f1_fuel_1994_12_1_0_7                 1         1994
# 1      f1_fuel_1994_12_1_0_10                 1         1994
# 2       f1_fuel_1994_12_2_0_1                 2         1994
# 3       f1_fuel_1994_12_2_0_7                 2         1994
# 5      f1_fuel_1994_12_2_0_13                 2         1994
# ...                       ...               ...          ...
# 1224  f1_fuel_1994_12_45_0_10                45         1994
# 1227   f1_fuel_1994_12_45_1_1                45         1994
# 1229   f1_fuel_1994_12_45_1_7                45         1994
# 1230  f1_fuel_1994_12_45_1_10                45         1994
# 1232   f1_fuel_1994_12_45_2_1                45         1994
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 0                 rockport                coal       ton        5377489.0
# 1     rockport total plant                coal       ton       10486945.0
# ...

# %%
df_1998=coal_g.groupby('report_year').get_group(1998)

# %%
df_1998
# Out:
#                      record_id  utility_id_ferc1  report_year  \
# 4618     f1_fuel_1998_12_1_0_7                 1         1998
# 4619    f1_fuel_1998_12_1_0_10                 1         1998
# 4620     f1_fuel_1998_12_4_0_1                 4         1998
# 4622     f1_fuel_1998_12_4_0_4                 4         1998
# 4624     f1_fuel_1998_12_6_0_1                 6         1998
# ...                        ...               ...          ...
# 5708  f1_fuel_1998_12_145_0_10               145         1998
# 5710  f1_fuel_1998_12_145_0_13               145         1998
# 5712   f1_fuel_1998_12_145_1_1               145         1998
# 5714   f1_fuel_1998_12_145_1_4               145         1998
# 5716   f1_fuel_1998_12_145_1_7               145         1998
#
#           plant_name_ferc1 fuel_type_code_pudl fuel_unit  fuel_qty_burned  \
# 4618    rockport total aeg                coal       ton        4965881.0
# ...

# %%
percent=(df_1998['fuel_cost_per_unit_burned'].sum()/(df_1998['fuel_cost_per_unit_burned'].sum()+df_1994['fuel_cost_per_unit_burned'].sum()))*100

# %%
percent
# Out:
# 44.26868816125639

# %%
# cost per unit burned in 1998  
per=(df_1998['fuel_cost_per_unit_burned'].sum()/df_1994['fuel_cost_per_unit_burned'].sum())*100
per
# Out:
# 79.43234548173947
